# %% [markdown]
# # 02. Tiền xử lý dữ liệu và Trích xuất đặc trưng (Data Preprocessing)
# Notebook này thực hiện các bước làm sạch dữ liệu, xử lý giá trị thiếu, mã hóa đặc trưng và rời rạc hóa.

# %%
import pandas as pd
import sys
import os

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

from src.data.loader import DataLoader
from src.data.cleaner import DataCleaner

# %% [markdown]
# ## 1. Load Dữ liệu Raw

# %%
loader = DataLoader(config_path='../configs/params.yaml')
df_raw = loader.load_data()
df_raw.head()

# %% [markdown]
# ## 2. Làm sạch và Rời rạc hóa (Binning)

# %%
cleaner = DataCleaner(config_path='../configs/params.yaml')
df_cleaned = cleaner.run_pipeline(df_raw)
df_cleaned.head()

# %% [markdown]
# ## 3. Lưu dữ liệu đã xử lý

# %%
cleaner.save_processed_data(df_cleaned)
